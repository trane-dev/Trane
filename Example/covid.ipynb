# %%
import json

import pandas as pd
from datetime import datetime, timedelta

import trane
import featuretools as ft
import numpy as np
import sklearn
#print(sklearn.__version__)

# %%
df = pd.read_csv("covid19.csv")
df['DATE'] = df['Date'].apply(lambda x: datetime.strptime(x, "%m/%d/%y"))
df = df.sort_values(by=['Date'])
df= df.drop(['Deaths','Confirmed','Recovered','Lat','Long'], axis=1)
df.tail()
# Out:
#       Province/State Country/Region    Date       DATE
# 11933            NaN           Cuba  3/9/20 2020-03-09
# 11934            NaN         Cyprus  3/9/20 2020-03-09
# 11935            NaN        Czechia  3/9/20 2020-03-09
# 11922          Tibet          China  3/9/20 2020-03-09
# 11969            NaN         Guyana  3/9/20 2020-03-09

# %%
entity_col = "Country/Region"
df_ft = df.copy()
str_col_list = ['Country/Region', 'Province/State']
str_mappers = {}
for str_col in str_col_list:
    str_to_id = {}
    id_to_str = []
    n_entity = 0

    for item in set(df_ft[str_col]):
        str_to_id[item] = n_entity
        id_to_str.append(item)
        n_entity += 1

    if str_col == entity_col:
        df[str_col] = df[str_col].apply(lambda x: str_to_id[x])
    df_ft[str_col] = df_ft[str_col].apply(lambda x: str_to_id[x])
    str_mappers[str_col] = (str_to_id, id_to_str)


meta = trane.TableMeta(json.loads(open('meta_covid.json').read()))

df_ft.tail()
# Out:
#        Province/State  Country/Region    Date       DATE
# 11933               0             142  3/9/20 2020-03-09
# 11934               0              37  3/9/20 2020-03-09
# 11935               0             119  3/9/20 2020-03-09
# 11922              21             151  3/9/20 2020-03-09
# 11969               0              40  3/9/20 2020-03-09

# %%
cutoff_base = datetime.strptime("2020-01-09", "%Y-%m-%d")
cutoff_end = datetime.strptime("2020-03-09", "%Y-%m-%d")
cutoff_strategy = trane.FixWindowCutoffStrategy(entity_col, cutoff_base, cutoff_end, 1)

features = trane.FeaturetoolsWrapper(df_ft, entity_col, 'DATE',
                                        {'Country/Region': ft.variable_types.Categorical,
                                         'Province/State': ft.variable_types.Categorical
                                        }, 'cases')
features.compute_features(df_ft, cutoff_strategy, 5)
# Out:
# Built 19 features
# Elapsed: 00:15 | Progress: 100%|██████████
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity cases
#   warnings.warn(

# %%
features.features
# Out:
#                            COUNT(cases)  MODE(cases.Province/State) = 0.0  \
# Country/Region time
# 0              2020-01-08           0.0                             False
#                2020-01-09           0.0                             False
#                2020-01-10           0.0                             False
#                2020-01-11           0.0                             False
#                2020-01-12           0.0                             False
# ...                                 ...                               ...
# 176            2020-03-03           5.0                              True
#                2020-03-04           5.0                              True
#                2020-03-05           5.0                              True
#                2020-03-06           5.0                              True
#                2020-03-07           5.0                              True
#
#                            MODE(cases.Province/State) = 8.0  \
# Country/Region time
# 0              2020-01-08                             False
#                2020-01-09                             False
#                2020-01-10                             False
#                2020-01-11                             False
#                2020-01-12                             False
# ...                                                     ...
# 176            2020-03-03                             False
#                2020-03-04                             False
#                2020-03-05                             False
#                2020-03-06                             False
#                2020-03-07                             False
#
#                            MODE(cases.Province/State) = 4.0  \
# Country/Region time
# 0              2020-01-08                             False
#                2020-01-09                             False
#                2020-01-10                             False
#                2020-01-11                             False
#                2020-01-12                             False
# ...                                                     ...
# 176            2020-03-03                             False
#                2020-03-04                             False
#                2020-03-05                             False
#                2020-03-06                             False
#                2020-03-07                             False
#
#                            MODE(cases.Province/State) = 1.0  \
# Country/Region time
# 0              2020-01-08                             False
#                2020-01-09                             False
#                2020-01-10                             False
#                2020-01-11                             False
#                2020-01-12                             False
# ...                                                     ...
# 176            2020-03-03                             False
#                2020-03-04                             False
#                2020-03-05                             False
#                2020-03-06                             False
#                2020-03-07                             False
#
#                            MODE(cases.Province/State) is unknown  \
# Country/Region time
# 0              2020-01-08                                   True
#                2020-01-09                                   True
#                2020-01-10                                   True
#                2020-01-11                                   True
#                2020-01-12                                   True
# ...                                                          ...
# 176            2020-03-03                                  False
#                2020-03-04                                  False
#                2020-03-05                                  False
#                2020-03-06                                  False
#                2020-03-07                                  False
#
#                            NUM_UNIQUE(cases.Province/State)  \
# Country/Region time
# 0              2020-01-08                               0.0
#                2020-01-09                               0.0
#                2020-01-10                               0.0
#                2020-01-11                               0.0
#                2020-01-12                               0.0
# ...                                                     ...
# 176            2020-03-03                               1.0
#                2020-03-04                               1.0
#                2020-03-05                               1.0
#                2020-03-06                               1.0
#                2020-03-07                               1.0
#
#                            MODE(cases.DAY(DATE)) = 1.0  \
# Country/Region time
# 0              2020-01-08                        False
#                2020-01-09                        False
#                2020-01-10                        False
#                2020-01-11                        False
#                2020-01-12                        False
# ...                                                ...
# 176            2020-03-03                         True
#                2020-03-04                         True
#                2020-03-05                         True
#                2020-03-06                        False
#                2020-03-07                        False
#
#                            MODE(cases.DAY(DATE)) = 22.0  \
# Country/Region time
# 0              2020-01-08                         False
#                2020-01-09                         False
#                2020-01-10                         False
#                2020-01-11                         False
#                2020-01-12                         False
# ...                                                 ...
# 176            2020-03-03                         False
#                2020-03-04                         False
#                2020-03-05                         False
#                2020-03-06                         False
#                2020-03-07                         False
#
#                            MODE(cases.DAY(DATE)) = 25.0  ...  \
# Country/Region time                                      ...
# 0              2020-01-08                         False  ...
#                2020-01-09                         False  ...
#                2020-01-10                         False  ...
#                2020-01-11                         False  ...
#                2020-01-12                         False  ...
# ...                                                 ...  ...
# 176            2020-03-03                         False  ...
#                2020-03-04                         False  ...
#                2020-03-05                         False  ...
#                2020-03-06                         False  ...
#                2020-03-07                         False  ...
#
#                            MODE(cases.YEAR(Date)) = 2020.0  \
# Country/Region time
# 0              2020-01-08                            False
#                2020-01-09                            False
#                2020-01-10                            False
#                2020-01-11                            False
#                2020-01-12                            False
# ...                                                    ...
# 176            2020-03-03                             True
#                2020-03-04                             True
#                2020-03-05                             True
#                2020-03-06                             True
#                2020-03-07                             True
#
#                            MODE(cases.YEAR(Date)) is unknown  \
# Country/Region time
# 0              2020-01-08                               True
#                2020-01-09                               True
#                2020-01-10                               True
#                2020-01-11                               True
#                2020-01-12                               True
# ...                                                      ...
# 176            2020-03-03                              False
#                2020-03-04                              False
#                2020-03-05                              False
#                2020-03-06                              False
#                2020-03-07                              False
#
#                            NUM_UNIQUE(cases.DAY(DATE))  \
# Country/Region time
# 0              2020-01-08                          0.0
#                2020-01-09                          0.0
#                2020-01-10                          0.0
#                2020-01-11                          0.0
#                2020-01-12                          0.0
# ...                                                ...
# 176            2020-03-03                          5.0
#                2020-03-04                          5.0
#                2020-03-05                          5.0
#                2020-03-06                          5.0
#                2020-03-07                          5.0
#
#                            NUM_UNIQUE(cases.DAY(Date))  \
# Country/Region time
# 0              2020-01-08                          0.0
#                2020-01-09                          0.0
#                2020-01-10                          0.0
#                2020-01-11                          0.0
#                2020-01-12                          0.0
# ...                                                ...
# 176            2020-03-03                          5.0
#                2020-03-04                          5.0
#                2020-03-05                          5.0
#                2020-03-06                          5.0
#                2020-03-07                          5.0
#
#                            NUM_UNIQUE(cases.MONTH(DATE))  \
# Country/Region time
# 0              2020-01-08                            0.0
#                2020-01-09                            0.0
#                2020-01-10                            0.0
#                2020-01-11                            0.0
#                2020-01-12                            0.0
# ...                                                  ...
# 176            2020-03-03                            2.0
#                2020-03-04                            2.0
#                2020-03-05                            1.0
#                2020-03-06                            1.0
#                2020-03-07                            1.0
#
#                            NUM_UNIQUE(cases.MONTH(Date))  \
# Country/Region time
# 0              2020-01-08                            0.0
#                2020-01-09                            0.0
#                2020-01-10                            0.0
#                2020-01-11                            0.0
#                2020-01-12                            0.0
# ...                                                  ...
# 176            2020-03-03                            2.0
#                2020-03-04                            2.0
#                2020-03-05                            1.0
#                2020-03-06                            1.0
#                2020-03-07                            1.0
#
#                            NUM_UNIQUE(cases.WEEKDAY(DATE))  \
# Country/Region time
# 0              2020-01-08                              0.0
#                2020-01-09                              0.0
#                2020-01-10                              0.0
#                2020-01-11                              0.0
#                2020-01-12                              0.0
# ...                                                    ...
# 176            2020-03-03                              5.0
#                2020-03-04                              5.0
#                2020-03-05                              5.0
#                2020-03-06                              5.0
#                2020-03-07                              5.0
#
#                            NUM_UNIQUE(cases.WEEKDAY(Date))  \
# Country/Region time
# 0              2020-01-08                              0.0
#                2020-01-09                              0.0
#                2020-01-10                              0.0
#                2020-01-11                              0.0
#                2020-01-12                              0.0
# ...                                                    ...
# 176            2020-03-03                              5.0
#                2020-03-04                              5.0
#                2020-03-05                              5.0
#                2020-03-06                              5.0
#                2020-03-07                              5.0
#
#                            NUM_UNIQUE(cases.YEAR(DATE))  \
# Country/Region time
# 0              2020-01-08                           0.0
#                2020-01-09                           0.0
#                2020-01-10                           0.0
#                2020-01-11                           0.0
#                2020-01-12                           0.0
# ...                                                 ...
# 176            2020-03-03                           1.0
#                2020-03-04                           1.0
#                2020-03-05                           1.0
#                2020-03-06                           1.0
#                2020-03-07                           1.0
#
#                            NUM_UNIQUE(cases.YEAR(Date))
# Country/Region time
# 0              2020-01-08                           0.0
#                2020-01-09                           0.0
#                2020-01-10                           0.0
#                2020-01-11                           0.0
#                2020-01-12                           0.0
# ...                                                 ...
# 176            2020-03-03                           1.0
#                2020-03-04                           1.0
#                2020-03-05                           1.0
#                2020-03-06                           1.0
#                2020-03-07                           1.0
#
# [10620 rows x 57 columns]

# %%
problem_generator = trane.PredictionProblemGenerator(
    table_meta=meta, entity_col=entity_col, time_col="Data")

problems = problem_generator.generate()
# Out:
# Success/Attempt = 231/1044

# %%
new_df = df[df['DATE'] < "2020-02-15"]
evaluator = trane.PredictionProblemEvaluator(new_df,
                                             entity_col=entity_col,
                                             cutoff_strategy=cutoff_strategy,
                                             min_train_set=20,
                                             min_test_set=20,
                                             previous_k_as_feature=2,
                                             latest_k_as_test=8
                                             )

# %%
for i in problems:
    print(i)
# Out:
# For each <Country/Region> predict the number of records
# For each <Country/Region> predict the number of records with <Lat> greater than __
# For each <Country/Region> predict the number of records with <Long> greater than __
# For each <Country/Region> predict the number of records with <Confirmed> greater than __
# For each <Country/Region> predict the number of records with <Deaths> greater than __
# For each <Country/Region> predict the number of records with <Recovered> greater than __
# For each <Country/Region> predict the number of records with <Lat> less than __
# For each <Country/Region> predict the number of records with <Long> less than __
# For each <Country/Region> predict the number of records with <Confirmed> less than __
# For each <Country/Region> predict the number of records with <Deaths> less than __
# For each <Country/Region> predict the number of records with <Recovered> less than __
# For each <Country/Region> predict the total <Lat> in all related records
# For each <Country/Region> predict the total <Long> in all related records
# For each <Country/Region> predict the total <Confirmed> in all related records
# For each <Country/Region> predict the total <Deaths> in all related records
# For each <Country/Region> predict the total <Recovered> in all related records
# For each <Country/Region> predict the total <Lat> in all related records with <Lat> greater than __
# For each <Country/Region> predict the total <Long> in all related records with <Lat> greater than __
# For each <Country/Region> predict the total <Confirmed> in all related records with <Lat> greater than __
# For each <Country/Region> predict the total <Deaths> in all related records with <Lat> greater than __
# For each <Country/Region> predict the total <Recovered> in all related records with <Lat> greater than __
# For each <Country/Region> predict the total <Lat> in all related records with <Long> greater than __
# For each <Country/Region> predict the total <Long> in all related records with <Long> greater than __
# For each <Country/Region> predict the total <Confirmed> in all related records with <Long> greater than __
# For each <Country/Region> predict the total <Deaths> in all related records with <Long> greater than __
# For each <Country/Region> predict the total <Recovered> in all related records with <Long> greater than __
# For each <Country/Region> predict the total <Lat> in all related records with <Confirmed> greater than __
# For each <Country/Region> predict the total <Long> in all related records with <Confirmed> greater than __
# For each <Country/Region> predict the total <Confirmed> in all related records with <Confirmed> greater than __
# For each <Country/Region> predict the total <Deaths> in all related records with <Confirmed> greater than __
# For each <Country/Region> predict the total <Recovered> in all related records with <Confirmed> greater than __
# For each <Country/Region> predict the total <Lat> in all related records with <Deaths> greater than __
# For each <Country/Region> predict the total <Long> in all related records with <Deaths> greater than __
# For each <Country/Region> predict the total <Confirmed> in all related records with <Deaths> greater than __
# For each <Country/Region> predict the total <Deaths> in all related records with <Deaths> greater than __
# For each <Country/Region> predict the total <Recovered> in all related records with <Deaths> greater than __
# For each <Country/Region> predict the total <Lat> in all related records with <Recovered> greater than __
# For each <Country/Region> predict the total <Long> in all related records with <Recovered> greater than __
# For each <Country/Region> predict the total <Confirmed> in all related records with <Recovered> greater than __
# For each <Country/Region> predict the total <Deaths> in all related records with <Recovered> greater than __
# For each <Country/Region> predict the total <Recovered> in all related records with <Recovered> greater than __
# For each <Country/Region> predict the total <Lat> in all related records with <Lat> less than __
# For each <Country/Region> predict the total <Long> in all related records with <Lat> less than __
# For each <Country/Region> predict the total <Confirmed> in all related records with <Lat> less than __
# For each <Country/Region> predict the total <Deaths> in all related records with <Lat> less than __
# For each <Country/Region> predict the total <Recovered> in all related records with <Lat> less than __
# For each <Country/Region> predict the total <Lat> in all related records with <Long> less than __
# For each <Country/Region> predict the total <Long> in all related records with <Long> less than __
# For each <Country/Region> predict the total <Confirmed> in all related records with <Long> less than __
# For each <Country/Region> predict the total <Deaths> in all related records with <Long> less than __
# For each <Country/Region> predict the total <Recovered> in all related records with <Long> less than __
# For each <Country/Region> predict the total <Lat> in all related records with <Confirmed> less than __
# For each <Country/Region> predict the total <Long> in all related records with <Confirmed> less than __
# For each <Country/Region> predict the total <Confirmed> in all related records with <Confirmed> less than __
# For each <Country/Region> predict the total <Deaths> in all related records with <Confirmed> less than __
# For each <Country/Region> predict the total <Recovered> in all related records with <Confirmed> less than __
# For each <Country/Region> predict the total <Lat> in all related records with <Deaths> less than __
# For each <Country/Region> predict the total <Long> in all related records with <Deaths> less than __
# For each <Country/Region> predict the total <Confirmed> in all related records with <Deaths> less than __
# For each <Country/Region> predict the total <Deaths> in all related records with <Deaths> less than __
# For each <Country/Region> predict the total <Recovered> in all related records with <Deaths> less than __
# For each <Country/Region> predict the total <Lat> in all related records with <Recovered> less than __
# For each <Country/Region> predict the total <Long> in all related records with <Recovered> less than __
# For each <Country/Region> predict the total <Confirmed> in all related records with <Recovered> less than __
# For each <Country/Region> predict the total <Deaths> in all related records with <Recovered> less than __
# For each <Country/Region> predict the total <Recovered> in all related records with <Recovered> less than __
# For each <Country/Region> predict the average of <Lat> in all related records
# For each <Country/Region> predict the average of <Long> in all related records
# For each <Country/Region> predict the average of <Confirmed> in all related records
# For each <Country/Region> predict the average of <Deaths> in all related records
# For each <Country/Region> predict the average of <Recovered> in all related records
# For each <Country/Region> predict the average of <Lat> in all related records with <Lat> greater than __
# For each <Country/Region> predict the average of <Long> in all related records with <Lat> greater than __
# For each <Country/Region> predict the average of <Confirmed> in all related records with <Lat> greater than __
# For each <Country/Region> predict the average of <Deaths> in all related records with <Lat> greater than __
# For each <Country/Region> predict the average of <Recovered> in all related records with <Lat> greater than __
# For each <Country/Region> predict the average of <Lat> in all related records with <Long> greater than __
# For each <Country/Region> predict the average of <Long> in all related records with <Long> greater than __
# For each <Country/Region> predict the average of <Confirmed> in all related records with <Long> greater than __
# For each <Country/Region> predict the average of <Deaths> in all related records with <Long> greater than __
# For each <Country/Region> predict the average of <Recovered> in all related records with <Long> greater than __
# For each <Country/Region> predict the average of <Lat> in all related records with <Confirmed> greater than __
# For each <Country/Region> predict the average of <Long> in all related records with <Confirmed> greater than __
# For each <Country/Region> predict the average of <Confirmed> in all related records with <Confirmed> greater than __
# For each <Country/Region> predict the average of <Deaths> in all related records with <Confirmed> greater than __
# For each <Country/Region> predict the average of <Recovered> in all related records with <Confirmed> greater than __
# For each <Country/Region> predict the average of <Lat> in all related records with <Deaths> greater than __
# For each <Country/Region> predict the average of <Long> in all related records with <Deaths> greater than __
# For each <Country/Region> predict the average of <Confirmed> in all related records with <Deaths> greater than __
# For each <Country/Region> predict the average of <Deaths> in all related records with <Deaths> greater than __
# For each <Country/Region> predict the average of <Recovered> in all related records with <Deaths> greater than __
# For each <Country/Region> predict the average of <Lat> in all related records with <Recovered> greater than __
# For each <Country/Region> predict the average of <Long> in all related records with <Recovered> greater than __
# For each <Country/Region> predict the average of <Confirmed> in all related records with <Recovered> greater than __
# For each <Country/Region> predict the average of <Deaths> in all related records with <Recovered> greater than __
# For each <Country/Region> predict the average of <Recovered> in all related records with <Recovered> greater than __
# For each <Country/Region> predict the average of <Lat> in all related records with <Lat> less than __
# For each <Country/Region> predict the average of <Long> in all related records with <Lat> less than __
# For each <Country/Region> predict the average of <Confirmed> in all related records with <Lat> less than __
# For each <Country/Region> predict the average of <Deaths> in all related records with <Lat> less than __
# For each <Country/Region> predict the average of <Recovered> in all related records with <Lat> less than __
# For each <Country/Region> predict the average of <Lat> in all related records with <Long> less than __
# For each <Country/Region> predict the average of <Long> in all related records with <Long> less than __
# For each <Country/Region> predict the average of <Confirmed> in all related records with <Long> less than __
# For each <Country/Region> predict the average of <Deaths> in all related records with <Long> less than __
# For each <Country/Region> predict the average of <Recovered> in all related records with <Long> less than __
# For each <Country/Region> predict the average of <Lat> in all related records with <Confirmed> less than __
# For each <Country/Region> predict the average of <Long> in all related records with <Confirmed> less than __
# For each <Country/Region> predict the average of <Confirmed> in all related records with <Confirmed> less than __
# For each <Country/Region> predict the average of <Deaths> in all related records with <Confirmed> less than __
# For each <Country/Region> predict the average of <Recovered> in all related records with <Confirmed> less than __
# For each <Country/Region> predict the average of <Lat> in all related records with <Deaths> less than __
# For each <Country/Region> predict the average of <Long> in all related records with <Deaths> less than __
# For each <Country/Region> predict the average of <Confirmed> in all related records with <Deaths> less than __
# For each <Country/Region> predict the average of <Deaths> in all related records with <Deaths> less than __
# For each <Country/Region> predict the average of <Recovered> in all related records with <Deaths> less than __
# For each <Country/Region> predict the average of <Lat> in all related records with <Recovered> less than __
# For each <Country/Region> predict the average of <Long> in all related records with <Recovered> less than __
# For each <Country/Region> predict the average of <Confirmed> in all related records with <Recovered> less than __
# For each <Country/Region> predict the average of <Deaths> in all related records with <Recovered> less than __
# For each <Country/Region> predict the average of <Recovered> in all related records with <Recovered> less than __
# For each <Country/Region> predict the maximum of <Lat> in all related records
# For each <Country/Region> predict the maximum of <Long> in all related records
# For each <Country/Region> predict the maximum of <Confirmed> in all related records
# For each <Country/Region> predict the maximum of <Deaths> in all related records
# For each <Country/Region> predict the maximum of <Recovered> in all related records
# For each <Country/Region> predict the maximum of <Lat> in all related records with <Lat> greater than __
# For each <Country/Region> predict the maximum of <Long> in all related records with <Lat> greater than __
# For each <Country/Region> predict the maximum of <Confirmed> in all related records with <Lat> greater than __
# For each <Country/Region> predict the maximum of <Deaths> in all related records with <Lat> greater than __
# For each <Country/Region> predict the maximum of <Recovered> in all related records with <Lat> greater than __
# For each <Country/Region> predict the maximum of <Lat> in all related records with <Long> greater than __
# For each <Country/Region> predict the maximum of <Long> in all related records with <Long> greater than __
# For each <Country/Region> predict the maximum of <Confirmed> in all related records with <Long> greater than __
# For each <Country/Region> predict the maximum of <Deaths> in all related records with <Long> greater than __
# For each <Country/Region> predict the maximum of <Recovered> in all related records with <Long> greater than __
# For each <Country/Region> predict the maximum of <Lat> in all related records with <Confirmed> greater than __
# For each <Country/Region> predict the maximum of <Long> in all related records with <Confirmed> greater than __
# For each <Country/Region> predict the maximum of <Confirmed> in all related records with <Confirmed> greater than __
# For each <Country/Region> predict the maximum of <Deaths> in all related records with <Confirmed> greater than __
# For each <Country/Region> predict the maximum of <Recovered> in all related records with <Confirmed> greater than __
# For each <Country/Region> predict the maximum of <Lat> in all related records with <Deaths> greater than __
# For each <Country/Region> predict the maximum of <Long> in all related records with <Deaths> greater than __
# For each <Country/Region> predict the maximum of <Confirmed> in all related records with <Deaths> greater than __
# For each <Country/Region> predict the maximum of <Deaths> in all related records with <Deaths> greater than __
# For each <Country/Region> predict the maximum of <Recovered> in all related records with <Deaths> greater than __
# For each <Country/Region> predict the maximum of <Lat> in all related records with <Recovered> greater than __
# For each <Country/Region> predict the maximum of <Long> in all related records with <Recovered> greater than __
# For each <Country/Region> predict the maximum of <Confirmed> in all related records with <Recovered> greater than __
# For each <Country/Region> predict the maximum of <Deaths> in all related records with <Recovered> greater than __
# For each <Country/Region> predict the maximum of <Recovered> in all related records with <Recovered> greater than __
# For each <Country/Region> predict the maximum of <Lat> in all related records with <Lat> less than __
# For each <Country/Region> predict the maximum of <Long> in all related records with <Lat> less than __
# For each <Country/Region> predict the maximum of <Confirmed> in all related records with <Lat> less than __
# For each <Country/Region> predict the maximum of <Deaths> in all related records with <Lat> less than __
# For each <Country/Region> predict the maximum of <Recovered> in all related records with <Lat> less than __
# For each <Country/Region> predict the maximum of <Lat> in all related records with <Long> less than __
# For each <Country/Region> predict the maximum of <Long> in all related records with <Long> less than __
# For each <Country/Region> predict the maximum of <Confirmed> in all related records with <Long> less than __
# For each <Country/Region> predict the maximum of <Deaths> in all related records with <Long> less than __
# For each <Country/Region> predict the maximum of <Recovered> in all related records with <Long> less than __
# For each <Country/Region> predict the maximum of <Lat> in all related records with <Confirmed> less than __
# For each <Country/Region> predict the maximum of <Long> in all related records with <Confirmed> less than __
# For each <Country/Region> predict the maximum of <Confirmed> in all related records with <Confirmed> less than __
# For each <Country/Region> predict the maximum of <Deaths> in all related records with <Confirmed> less than __
# For each <Country/Region> predict the maximum of <Recovered> in all related records with <Confirmed> less than __
# For each <Country/Region> predict the maximum of <Lat> in all related records with <Deaths> less than __
# For each <Country/Region> predict the maximum of <Long> in all related records with <Deaths> less than __
# For each <Country/Region> predict the maximum of <Confirmed> in all related records with <Deaths> less than __
# For each <Country/Region> predict the maximum of <Deaths> in all related records with <Deaths> less than __
# For each <Country/Region> predict the maximum of <Recovered> in all related records with <Deaths> less than __
# For each <Country/Region> predict the maximum of <Lat> in all related records with <Recovered> less than __
# For each <Country/Region> predict the maximum of <Long> in all related records with <Recovered> less than __
# For each <Country/Region> predict the maximum of <Confirmed> in all related records with <Recovered> less than __
# For each <Country/Region> predict the maximum of <Deaths> in all related records with <Recovered> less than __
# For each <Country/Region> predict the maximum of <Recovered> in all related records with <Recovered> less than __
# For each <Country/Region> predict the minimum of <Lat> in all related records
# For each <Country/Region> predict the minimum of <Long> in all related records
# For each <Country/Region> predict the minimum of <Confirmed> in all related records
# For each <Country/Region> predict the minimum of <Deaths> in all related records
# For each <Country/Region> predict the minimum of <Recovered> in all related records
# For each <Country/Region> predict the minimum of <Lat> in all related records with <Lat> greater than __
# For each <Country/Region> predict the minimum of <Long> in all related records with <Lat> greater than __
# For each <Country/Region> predict the minimum of <Confirmed> in all related records with <Lat> greater than __
# For each <Country/Region> predict the minimum of <Deaths> in all related records with <Lat> greater than __
# For each <Country/Region> predict the minimum of <Recovered> in all related records with <Lat> greater than __
# For each <Country/Region> predict the minimum of <Lat> in all related records with <Long> greater than __
# For each <Country/Region> predict the minimum of <Long> in all related records with <Long> greater than __
# For each <Country/Region> predict the minimum of <Confirmed> in all related records with <Long> greater than __
# For each <Country/Region> predict the minimum of <Deaths> in all related records with <Long> greater than __
# For each <Country/Region> predict the minimum of <Recovered> in all related records with <Long> greater than __
# For each <Country/Region> predict the minimum of <Lat> in all related records with <Confirmed> greater than __
# For each <Country/Region> predict the minimum of <Long> in all related records with <Confirmed> greater than __
# For each <Country/Region> predict the minimum of <Confirmed> in all related records with <Confirmed> greater than __
# For each <Country/Region> predict the minimum of <Deaths> in all related records with <Confirmed> greater than __
# For each <Country/Region> predict the minimum of <Recovered> in all related records with <Confirmed> greater than __
# For each <Country/Region> predict the minimum of <Lat> in all related records with <Deaths> greater than __
# For each <Country/Region> predict the minimum of <Long> in all related records with <Deaths> greater than __
# For each <Country/Region> predict the minimum of <Confirmed> in all related records with <Deaths> greater than __
# For each <Country/Region> predict the minimum of <Deaths> in all related records with <Deaths> greater than __
# For each <Country/Region> predict the minimum of <Recovered> in all related records with <Deaths> greater than __
# For each <Country/Region> predict the minimum of <Lat> in all related records with <Recovered> greater than __
# For each <Country/Region> predict the minimum of <Long> in all related records with <Recovered> greater than __
# For each <Country/Region> predict the minimum of <Confirmed> in all related records with <Recovered> greater than __
# For each <Country/Region> predict the minimum of <Deaths> in all related records with <Recovered> greater than __
# For each <Country/Region> predict the minimum of <Recovered> in all related records with <Recovered> greater than __
# For each <Country/Region> predict the minimum of <Lat> in all related records with <Lat> less than __
# For each <Country/Region> predict the minimum of <Long> in all related records with <Lat> less than __
# For each <Country/Region> predict the minimum of <Confirmed> in all related records with <Lat> less than __
# For each <Country/Region> predict the minimum of <Deaths> in all related records with <Lat> less than __
# For each <Country/Region> predict the minimum of <Recovered> in all related records with <Lat> less than __
# For each <Country/Region> predict the minimum of <Lat> in all related records with <Long> less than __
# For each <Country/Region> predict the minimum of <Long> in all related records with <Long> less than __
# For each <Country/Region> predict the minimum of <Confirmed> in all related records with <Long> less than __
# For each <Country/Region> predict the minimum of <Deaths> in all related records with <Long> less than __
# For each <Country/Region> predict the minimum of <Recovered> in all related records with <Long> less than __
# For each <Country/Region> predict the minimum of <Lat> in all related records with <Confirmed> less than __
# For each <Country/Region> predict the minimum of <Long> in all related records with <Confirmed> less than __
# For each <Country/Region> predict the minimum of <Confirmed> in all related records with <Confirmed> less than __
# For each <Country/Region> predict the minimum of <Deaths> in all related records with <Confirmed> less than __
# For each <Country/Region> predict the minimum of <Recovered> in all related records with <Confirmed> less than __
# For each <Country/Region> predict the minimum of <Lat> in all related records with <Deaths> less than __
# For each <Country/Region> predict the minimum of <Long> in all related records with <Deaths> less than __
# For each <Country/Region> predict the minimum of <Confirmed> in all related records with <Deaths> less than __
# For each <Country/Region> predict the minimum of <Deaths> in all related records with <Deaths> less than __
# For each <Country/Region> predict the minimum of <Recovered> in all related records with <Deaths> less than __
# For each <Country/Region> predict the minimum of <Lat> in all related records with <Recovered> less than __
# For each <Country/Region> predict the minimum of <Long> in all related records with <Recovered> less than __
# For each <Country/Region> predict the minimum of <Confirmed> in all related records with <Recovered> less than __
# For each <Country/Region> predict the minimum of <Deaths> in all related records with <Recovered> less than __
# For each <Country/Region> predict the minimum of <Recovered> in all related records with <Recovered> less than __

# %%
result = trane.multi_process_evaluation(evaluator, problems[50:100], features)
# Out:
#   0%|          | 0/50 [00:02<?, ?it/s]

# %%
len(problems)
# Out:
# 231
# ERROR! Session/line number was not unique in database. History logging moved to new session 250
# Process SpawnPoolWorker-2:
# Traceback (most recent call last):
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-8:
# Traceback (most recent call last):
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-3:
# Traceback (most recent call last):
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-1:
# Traceback (most recent call last):
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-5:
# Traceback (most recent call last):
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-7:
# Traceback (most recent call last):
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-6:
# Traceback (most recent call last):
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-4:
# Traceback (most recent call last):
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/queues.py", line 356, in get
#     res = self._reader.recv_bytes()
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/logging/__init__.py", line 2125, in shutdown
#     h.acquire()
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/logging/__init__.py", line 903, in acquire
#     self.lock.acquire()
# KeyboardInterrupt
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/logging/__init__.py", line 2118, in shutdown
#     for wr in reversed(handlerList[:]):
# KeyboardInterrupt
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/logging/__init__.py", line 2126, in shutdown
#     h.flush()
# KeyboardInterrupt
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/logging/__init__.py", line 2118, in shutdown
#     for wr in reversed(handlerList[:]):
# KeyboardInterrupt
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/logging/__init__.py", line 2126, in shutdown
#     h.flush()
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/logging/__init__.py", line 1069, in flush
#     self.stream.flush()
# KeyboardInterrupt
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/logging/__init__.py", line 2125, in shutdown
#     h.acquire()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/logging/__init__.py", line 2135, in shutdown
#     h.release()
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/logging/__init__.py", line 910, in release
#     self.lock.release()
# RuntimeError: cannot release un-acquired lock
# Exception ignored in: <module 'threading' from '/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/threading.py'>
# Traceback (most recent call last):
#   File "/Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/threading.py", line 1355, in _shutdown
#     def _shutdown():
# KeyboardInterrupt:
