# %%
import json

import pandas as pd
from datetime import datetime, timedelta

import trane
import featuretools as ft
import numpy as np

# %%
df = pd.read_csv("data/bike-sampled.csv")
df["date"] = df["date"].apply(lambda x: datetime.strptime(x, "%Y-%m-%d"))
df = df.sort_values(by=["date"])
df.tail()
# Out:
#            date  hour    usertype  gender  tripduration  temperature  \
# 3304 2017-01-31    10  Subscriber  Female      6.966667         37.9
# 3305 2017-01-31    10  Subscriber    Male      6.483333         37.9
# 3306 2017-01-31    10  Subscriber  Female      8.250000         37.9
# 3299 2017-01-31    10  Subscriber    Male     16.266667         37.9
# 0    2017-01-31    23  Subscriber    Male      3.316667         35.1
#
#       from_station_id  dpcapacity_start  to_station_id  dpcapacity_end
# 3304              247              19.0            247            19.0
# 3305              425              15.0            426            19.0
# 3306              175              19.0             45            15.0
# 3299              202              15.0            317            23.0
# 0                 230              19.0            131            15.0

# %%
entity_col = "__fake_root_entity__"
meta = trane.TableMeta(json.loads(open("data/meta.json").read()))
df, meta = trane.overall_prediction_helper(df, meta)

# MAP str to int
df_ft = df.copy()
str_col_list = ["usertype", "gender"]
str_mappers = {}
for str_col in str_col_list:
    str_to_id = {}
    id_to_str = []
    n_entity = 0

    for item in set(df_ft[str_col]):
        str_to_id[item] = n_entity
        id_to_str.append(item)
        n_entity += 1

    if str_col == entity_col:
        df[str_col] = df[str_col].apply(lambda x: str_to_id[x])
    df_ft[str_col] = df_ft[str_col].apply(lambda x: str_to_id[x])
    str_mappers[str_col] = (str_to_id, id_to_str)


df_ft.tail()
# Out:
#            date  hour  usertype  gender  tripduration  temperature  \
# 3304 2017-01-31    10         1       1      6.966667         37.9
# 3305 2017-01-31    10         1       0      6.483333         37.9
# 3306 2017-01-31    10         1       1      8.250000         37.9
# 3299 2017-01-31    10         1       0     16.266667         37.9
# 0    2017-01-31    23         1       0      3.316667         35.1
#
#       from_station_id  dpcapacity_start  to_station_id  dpcapacity_end  \
# 3304              247              19.0            247            19.0
# 3305              425              15.0            426            19.0
# 3306              175              19.0             45            15.0
# 3299              202              15.0            317            23.0
# 0                 230              19.0            131            15.0
#
#       __fake_root_entity__
# 3304                     0
# 3305                     0
# 3306                     0
# 3299                     0
# 0                        0

# %%
from datetime import datetime
import trane

cutoff_base = datetime.strptime("2017-01-06", "%Y-%m-%d")
cutoff_end = datetime.strptime("2017-01-31", "%Y-%m-%d")
cutoff_strategy = trane.FixWindowCutoffStrategy(entity_col, cutoff_base, cutoff_end, 1)

features = trane.FeaturetoolsWrapper(
    df=df_ft,
    entity_col=entity_col,
    time_col="date",
    logical_types={
        "hour": "Categorical",
        "usertype": "Categorical",
        "gender": "Categorical",
        "from_station_id": "Categorical",
        "to_station_id": "Categorical",
    },
    name="bikes",
)
features.compute_features(df_ft, cutoff_strategy, 5)
# Out:
# Built 43 features
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 21
#       6 cutoff_strategy = trane.FixWindowCutoffStrategy(entity_col, cutoff_base, cutoff_end, 1)
#       8 features = trane.FeaturetoolsWrapper(
#       9     df=df_ft,
#      10     entity_col=entity_col,
#    (...)
#      19     name="bikes",
#      20 )
# ---> 21 features.compute_features(df_ft, cutoff_strategy, 5)
#
# File ~/Trane/trane/utils/featuretools_wrapper.py:39, in FeaturetoolsWrapper.compute_features(self, df, cutoff_df, feature_window)
#      38 def compute_features(self, df, cutoff_df, feature_window):
# ---> 39     feature_matrix, features = ft.dfs(
#      40         target_dataframe_name=self.entity_col,
#      41         cutoff_time=cutoff_df,
#      42         entityset=self.es,
#      43         cutoff_time_in_index=True,
#      44         verbose=True,
#      45     )
#      47     # encode categorical values
#      48     fm_encoded, features_encoded = ft.encode_features(feature_matrix, features)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/featuretools/utils/entry_point.py:39, in entry_point.<locals>.inner_function.<locals>.function_wrapper(*args, **kwargs)
#      37     for ep in entry_points:
#      38         ep.on_error(error=e, runtime=runtime)
# ---> 39     raise e
#      41 # send return value
#      42 for ep in entry_points:
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/featuretools/utils/entry_point.py:32, in entry_point.<locals>.inner_function.<locals>.function_wrapper(*args, **kwargs)
#      29 try:
#      30     # call function
#      31     start = time.time()
# ---> 32     return_value = func(*args, **kwargs)
#      33     runtime = time.time() - start
#      34 except Exception as e:
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/featuretools/synthesis/dfs.py:283, in dfs(dataframes, relationships, entityset, target_dataframe_name, cutoff_time, instance_ids, agg_primitives, trans_primitives, groupby_trans_primitives, allowed_paths, max_depth, ignore_dataframes, ignore_columns, primitive_options, seed_features, drop_contains, drop_exact, where_primitives, max_features, cutoff_time_in_index, save_progress, features_only, training_window, approximate, chunk_size, n_jobs, dask_kwargs, verbose, return_types, progress_callback, include_cutoff_time)
#     277     return features
#     279 assert (
#     280     features != []
#     281 ), "No features can be generated from the specified primitives. Please make sure the primitives you are using are compatible with the variable types in your data."
# --> 283 feature_matrix = calculate_feature_matrix(
#     284     features,
#     285     entityset=entityset,
#     286     cutoff_time=cutoff_time,
#     287     instance_ids=instance_ids,
#     288     training_window=training_window,
#     289     approximate=approximate,
#     290     cutoff_time_in_index=cutoff_time_in_index,
#     291     save_progress=save_progress,
#     292     chunk_size=chunk_size,
#     293     n_jobs=n_jobs,
#     294     dask_kwargs=dask_kwargs,
#     295     verbose=verbose,
#     296     progress_callback=progress_callback,
#     297     include_cutoff_time=include_cutoff_time,
#     298 )
#     299 return feature_matrix, features
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/featuretools/computational_backends/calculate_feature_matrix.py:230, in calculate_feature_matrix(features, entityset, cutoff_time, instance_ids, dataframes, relationships, cutoff_time_in_index, training_window, approximate, save_progress, verbose, chunk_size, n_jobs, dask_kwargs, progress_callback, include_cutoff_time)
#     226         instance_ids = pd.Series(instance_ids)
#     228     cutoff_time = (cutoff_time, instance_ids)
# --> 230 _check_cutoff_time_type(cutoff_time, entityset.time_type)
#     232 # Approximate provides no benefit with a single cutoff time, so ignore it
#     233 if isinstance(cutoff_time, tuple) and approximate is not None:
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/featuretools/computational_backends/utils.py:311, in _check_cutoff_time_type(cutoff_time, es_time_type)
#     309 if isinstance(cutoff_time, tuple):
#     310     cutoff_time_value = cutoff_time[0]
# --> 311     time_type = _check_time_type(cutoff_time_value)
#     312     is_numeric = time_type == "numeric"
#     313     is_datetime = time_type == Datetime
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/featuretools/utils/wrangle.py:117, in _check_time_type(time)
#     113 if isinstance(time, (datetime, np.datetime64)):
#     114     time_type = Datetime
#     115 elif (
#     116     isinstance(time, (int, float))
# --> 117     or np.issubdtype(time, np.integer)
#     118     or np.issubdtype(time, np.floating)
#     119 ):
#     120     time_type = "numeric"
#     121 return time_type
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/numpy/core/numerictypes.py:416, in issubdtype(arg1, arg2)
#     358 r"""
#     359 Returns True if first argument is a typecode lower/equal in type hierarchy.
#     360
#    (...)
#     413
#     414 """
#     415 if not issubclass_(arg1, generic):
# --> 416     arg1 = dtype(arg1).type
#     417 if not issubclass_(arg2, generic):
#     418     arg2 = dtype(arg2).type
#
# TypeError: Cannot interpret '<trane.core.cutoff_strategy.FixWindowCutoffStrategy object at 0x14f73e190>' as a data type

# %%
problem_generator = trane.PredictionProblemGenerator(
    table_meta=meta, entity_col=entity_col, time_col="date"
)

problems = problem_generator.generate()

# %%
evaluator = trane.PredictionProblemEvaluator(
    df,
    entity_col=entity_col,
    cutoff_strategy=cutoff_strategy,
    min_train_set=5,
    min_test_set=5,
    previous_k_as_feature=2,
    latest_k_as_test=8,
)

# %%
result = trane.multi_process_evaluation(evaluator, problems, features)
with open("prob_with_acc.json", "w") as f:
    json.dump(result, f)
