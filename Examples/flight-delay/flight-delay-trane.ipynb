# %%
import json

import pandas as pd
from datetime import datetime, timedelta

import trane
import featuretools as ft
import numpy as np

print(ft.__version__)

# %%
df = pd.read_csv("flight-delays/flight-sampled.csv", dtype={"TAIL_NUMBER": str})
df["DATE"] = df["DATE"].apply(lambda x: datetime.strptime(x, "%Y-%m-%d"))
df = df.sort_values(by=["DATE"])
df.tail()

# %%
# entity_col = "__fake_root_entity__"
# df, meta = trane.overall_prediction_helper(df, meta)
entity_col = "AIRLINE"

# MAP str to int
df_ft = df.copy()
str_col_list = [
    "AIRLINE",
    "FLIGHT_NUMBER",
    "TAIL_NUMBER",
    "ORIGIN_AIRPORT",
    "DESTINATION_AIRPORT",
    "CANCELLATION_REASON",
]
str_mappers = {}
for str_col in str_col_list:
    str_to_id = {}
    id_to_str = []
    n_entity = 0

    for item in set(df_ft[str_col]):
        str_to_id[item] = n_entity
        id_to_str.append(item)
        n_entity += 1

    if str_col == entity_col:
        df[str_col] = df[str_col].apply(lambda x: str_to_id[x])
    df_ft[str_col] = df_ft[str_col].apply(lambda x: str_to_id[x])
    str_mappers[str_col] = (str_to_id, id_to_str)


meta = trane.TableMeta(json.loads(open("flight-delays/meta.json").read()))

df_ft.tail()
# Out:
#              DATE  DAY_OF_WEEK  AIRLINE  FLIGHT_NUMBER  TAIL_NUMBER  \
# 461945 2015-01-31            6        1           6737          443
# 461946 2015-01-31            6        5          14287         2278
# 461947 2015-01-31            6       13           8554         3462
# 461938 2015-01-31            6        1          13472          412
# 469967 2015-01-31            6        5          13335         2002
#
#         ORIGIN_AIRPORT  DESTINATION_AIRPORT  SCHEDULED_DEPARTURE_HOUR  \
# 461945              17                  169                        10
# 461946             161                  159                        10
# 461947             104                  308                        10
# 461938             150                   74                        10
# 469967              83                  169                        23
#
#         SCHEDULED_TIME  ELAPSED_TIME  DEPARTURE_DELAY  ARRIVAL_DELAY  \
# 461945            74.0          88.0             -1.0           13.0
# 461946           256.0         236.0             21.0            1.0
# 461947           148.0         162.0             -9.0            5.0
# 461938            85.0          80.0             -6.0          -11.0
# 469967           309.0         312.0             -1.0            2.0
#
#         CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  \
# 461945          0                    3               0.0             0.0
# 461946          0                    3               0.0             0.0
# 461947          0                    3               0.0             0.0
# 461938          0                    3               0.0             0.0
# 469967          0                    3               0.0             0.0
#
#         AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 461945            0.0                  0.0            0.0
# 461946            0.0                  0.0            0.0
# 461947            0.0                  0.0            0.0
# 461938            0.0                  0.0            0.0
# 469967            0.0                  0.0            0.0

# %%
cutoff_base = datetime.strptime("2015-01-06", "%Y-%m-%d")
cutoff_end = datetime.strptime("2015-01-31", "%Y-%m-%d")
cutoff_strategy = trane.FixWindowCutoffStrategy(entity_col, cutoff_base, cutoff_end, 1)

features = trane.FeaturetoolsWrapper(
    df_ft,
    entity_col,
    "DATE",
    {
        "DAY_OF_WEEK": ft.variable_types.Categorical,
        "AIRLINE": ft.variable_types.Categorical,
        "FLIGHT_NUMBER": ft.variable_types.Categorical,
        "TAIL_NUMBER": ft.variable_types.Categorical,
        "ORIGIN_AIRPORT": ft.variable_types.Categorical,
        "DESTINATION_AIRPORT": ft.variable_types.Categorical,
        "CANCELLED": ft.variable_types.Categorical,
        "CANCELLATION_REASON": ft.variable_types.Categorical,
    },
    "flights",
)
features.compute_features(df_ft, cutoff_strategy, 5)
# Out:
# Built 83 features
# Elapsed: 00:09 | Progress: 100%|██████████
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(
# /Users/sarapido/anaconda3/envs/Trane3.8/lib/python3.8/site-packages/featuretools/entityset/entityset.py:1019: UserWarning: Using training_window but last_time_index is not set on entity flights
#   warnings.warn(

# %%
features.features
# Out:
#                     COUNT(flights)  MAX(flights.AIRLINE_DELAY)  \
# AIRLINE time
# 0       2015-01-05            7537                      1380.0
#         2015-01-06            7464                      1380.0
#         2015-01-07            7339                      1380.0
#         2015-01-08            7333                      1222.0
#         2015-01-09            7247                      1033.0
# ...                            ...                         ...
# 13      2015-01-25            3413                       245.0
#         2015-01-26            3450                       251.0
#         2015-01-27            3407                       251.0
#         2015-01-28            3367                       251.0
#         2015-01-29            3452                       257.0
#
#                     MAX(flights.AIR_SYSTEM_DELAY)  MAX(flights.ARRIVAL_DELAY)  \
# AIRLINE time
# 0       2015-01-05                          207.0                      1384.0
#         2015-01-06                          207.0                      1384.0
#         2015-01-07                          207.0                      1384.0
#         2015-01-08                          205.0                      1237.0
#         2015-01-09                          172.0                      1187.0
# ...                                           ...                         ...
# 13      2015-01-25                          121.0                       249.0
#         2015-01-26                          152.0                       345.0
#         2015-01-27                          152.0                       345.0
#         2015-01-28                          152.0                       345.0
#         2015-01-29                          152.0                       345.0
#
#                     MAX(flights.DEPARTURE_DELAY)  MAX(flights.ELAPSED_TIME)  \
# AIRLINE time
# 0       2015-01-05                        1380.0                      544.0
#         2015-01-06                        1380.0                      544.0
#         2015-01-07                        1380.0                      525.0
#         2015-01-08                        1255.0                      523.0
#         2015-01-09                        1190.0                      520.0
# ...                                          ...                        ...
# 13      2015-01-25                         245.0                      441.0
#         2015-01-26                         306.0                      441.0
#         2015-01-27                         306.0                      441.0
#         2015-01-28                         306.0                      441.0
#         2015-01-29                         306.0                      438.0
#
#                     MAX(flights.LATE_AIRCRAFT_DELAY)  \
# AIRLINE time
# 0       2015-01-05                             891.0
#         2015-01-06                             891.0
#         2015-01-07                             891.0
#         2015-01-08                             729.0
#         2015-01-09                             729.0
# ...                                              ...
# 13      2015-01-25                             146.0
#         2015-01-26                             156.0
#         2015-01-27                             156.0
#         2015-01-28                             156.0
#         2015-01-29                             156.0
#
#                     MAX(flights.SCHEDULED_DEPARTURE_HOUR)  \
# AIRLINE time
# 0       2015-01-05                                     23
#         2015-01-06                                     23
#         2015-01-07                                     23
#         2015-01-08                                     23
#         2015-01-09                                     23
# ...                                                   ...
# 13      2015-01-25                                     23
#         2015-01-26                                     23
#         2015-01-27                                     23
#         2015-01-28                                     23
#         2015-01-29                                     23
#
#                     MAX(flights.SCHEDULED_TIME)  MAX(flights.SECURITY_DELAY)  \
# AIRLINE time
# 0       2015-01-05                        515.0                         61.0
#         2015-01-06                        523.0                         61.0
#         2015-01-07                        523.0                         61.0
#         2015-01-08                        523.0                         21.0
#         2015-01-09                        523.0                         15.0
# ...                                         ...                          ...
# 13      2015-01-25                        412.0                         98.0
#         2015-01-26                        412.0                         98.0
#         2015-01-27                        412.0                         98.0
#         2015-01-28                        412.0                         98.0
#         2015-01-29                        412.0                         98.0
#
#                     ...  MODE(flights.WEEKDAY(DATE)) = 6  \
# AIRLINE time        ...
# 0       2015-01-05  ...                            False
#         2015-01-06  ...                            False
#         2015-01-07  ...                             True
#         2015-01-08  ...                             True
#         2015-01-09  ...                            False
# ...                 ...                              ...
# 13      2015-01-25  ...                            False
#         2015-01-26  ...                            False
#         2015-01-27  ...                            False
#         2015-01-28  ...                            False
#         2015-01-29  ...                            False
#
#                     MODE(flights.WEEKDAY(DATE)) = 1  \
# AIRLINE time
# 0       2015-01-05                            False
#         2015-01-06                            False
#         2015-01-07                            False
#         2015-01-08                            False
#         2015-01-09                            False
# ...                                             ...
# 13      2015-01-25                            False
#         2015-01-26                            False
#         2015-01-27                            False
#         2015-01-28                            False
#         2015-01-29                            False
#
#                     MODE(flights.WEEKDAY(DATE)) = 2  \
# AIRLINE time
# 0       2015-01-05                            False
#         2015-01-06                            False
#         2015-01-07                            False
#         2015-01-08                            False
#         2015-01-09                            False
# ...                                             ...
# 13      2015-01-25                            False
#         2015-01-26                            False
#         2015-01-27                            False
#         2015-01-28                            False
#         2015-01-29                            False
#
#                     MODE(flights.WEEKDAY(DATE)) is unknown  \
# AIRLINE time
# 0       2015-01-05                                   False
#         2015-01-06                                   False
#         2015-01-07                                   False
#         2015-01-08                                   False
#         2015-01-09                                   False
# ...                                                    ...
# 13      2015-01-25                                   False
#         2015-01-26                                   False
#         2015-01-27                                   False
#         2015-01-28                                   False
#         2015-01-29                                   False
#
#                     MODE(flights.YEAR(DATE)) = 2015  \
# AIRLINE time
# 0       2015-01-05                             True
#         2015-01-06                             True
#         2015-01-07                             True
#         2015-01-08                             True
#         2015-01-09                             True
# ...                                             ...
# 13      2015-01-25                             True
#         2015-01-26                             True
#         2015-01-27                             True
#         2015-01-28                             True
#         2015-01-29                             True
#
#                     MODE(flights.YEAR(DATE)) is unknown  \
# AIRLINE time
# 0       2015-01-05                                False
#         2015-01-06                                False
#         2015-01-07                                False
#         2015-01-08                                False
#         2015-01-09                                False
# ...                                                 ...
# 13      2015-01-25                                False
#         2015-01-26                                False
#         2015-01-27                                False
#         2015-01-28                                False
#         2015-01-29                                False
#
#                     NUM_UNIQUE(flights.DAY(DATE))  \
# AIRLINE time
# 0       2015-01-05                              5
#         2015-01-06                              5
#         2015-01-07                              5
#         2015-01-08                              5
#         2015-01-09                              5
# ...                                           ...
# 13      2015-01-25                              5
#         2015-01-26                              5
#         2015-01-27                              5
#         2015-01-28                              5
#         2015-01-29                              5
#
#                     NUM_UNIQUE(flights.MONTH(DATE))  \
# AIRLINE time
# 0       2015-01-05                                1
#         2015-01-06                                1
#         2015-01-07                                1
#         2015-01-08                                1
#         2015-01-09                                1
# ...                                             ...
# 13      2015-01-25                                1
#         2015-01-26                                1
#         2015-01-27                                1
#         2015-01-28                                1
#         2015-01-29                                1
#
#                     NUM_UNIQUE(flights.WEEKDAY(DATE))  \
# AIRLINE time
# 0       2015-01-05                                  5
#         2015-01-06                                  5
#         2015-01-07                                  5
#         2015-01-08                                  5
#         2015-01-09                                  5
# ...                                               ...
# 13      2015-01-25                                  5
#         2015-01-26                                  5
#         2015-01-27                                  5
#         2015-01-28                                  5
#         2015-01-29                                  5
#
#                     NUM_UNIQUE(flights.YEAR(DATE))
# AIRLINE time
# 0       2015-01-05                               1
#         2015-01-06                               1
#         2015-01-07                               1
#         2015-01-08                               1
#         2015-01-09                               1
# ...                                            ...
# 13      2015-01-25                               1
#         2015-01-26                               1
#         2015-01-27                               1
#         2015-01-28                               1
#         2015-01-29                               1
#
# [350 rows x 149 columns]

# %%
problem_generator = trane.PredictionProblemGenerator(
    table_meta=meta, entity_col=entity_col, time_col="DATE"
)

problems = problem_generator.generate()
# Out:
# Success/Attempt = 1680/6643

# %%
new_df = df[df["DATE"] < "2015-01-15"]
evaluator = trane.PredictionProblemEvaluator(
    new_df,
    entity_col=entity_col,
    cutoff_strategy=cutoff_strategy,
    min_train_set=20,
    min_test_set=20,
    previous_k_as_feature=2,
    latest_k_as_test=8,
)

# %%
result = trane.multi_process_evaluation(evaluator, problems, features)
# with open("prob_with_acc.json", "w") as f:
#     json.dump(result, f)
# Out:
# 100%|██████████| 1680/1680 [18:43<00:00,  1.50it/s]

# %%
result
# Out:
# [{'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records',
#   'evaluations': [{'description': 'no threshold',
#     'problem': 'For each <AIRLINE> predict the number of records in next 1 days',
#     'label_stats': {'overall_mean': 390.2542857142857,
#      'overall_std': 728.5766404799575,
#      'entity_std': 522.9609449837188},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <SCHEDULED_DEPARTURE_HOUR> greater than __',
#   'evaluations': [{'description': 'threshold: 16 (keep 25.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <SCHEDULED_DEPARTURE_HOUR> greater than 16 in next 1 days',
#     'label_stats': {'overall_mean': 105.86,
#      'overall_std': 197.88314112843756,
#      'entity_std': 143.17532655099714},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 12 (keep 50.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <SCHEDULED_DEPARTURE_HOUR> greater than 12 in next 1 days',
#     'label_stats': {'overall_mean': 204.46571428571428,
#      'overall_std': 383.22115617326705,
#      'entity_std': 274.77007318909796},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 8 (keep 75.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <SCHEDULED_DEPARTURE_HOUR> greater than 8 in next 1 days',
#     'label_stats': {'overall_mean': 303.22285714285715,
#      'overall_std': 567.8644723048999,
#      'entity_std': 406.5033406459029},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <SCHEDULED_TIME> greater than __',
#   'evaluations': [{'description': 'threshold: 176.0 (keep 25.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <SCHEDULED_TIME> greater than 176.0 in next 1 days',
#     'label_stats': {'overall_mean': 89.84571428571428,
#      'overall_std': 181.31018148522185,
#      'entity_std': 120.21219810359072},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 123.0 (keep 50.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <SCHEDULED_TIME> greater than 123.0 in next 1 days',
#     'label_stats': {'overall_mean': 189.13142857142856,
#      'overall_std': 358.3403248879706,
#      'entity_std': 253.1332731237688},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 87.0 (keep 75.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <SCHEDULED_TIME> greater than 87.0 in next 1 days',
#     'label_stats': {'overall_mean': 284.04285714285714,
#      'overall_std': 528.2756108513889,
#      'entity_std': 380.5438486429687},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <ELAPSED_TIME> greater than __',
#   'evaluations': [{'description': 'threshold: 172.0 (keep 25.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <ELAPSED_TIME> greater than 172.0 in next 1 days',
#     'label_stats': {'overall_mean': 89.87428571428572,
#      'overall_std': 176.7605035761377,
#      'entity_std': 120.74020004630036},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 119.0 (keep 50.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <ELAPSED_TIME> greater than 119.0 in next 1 days',
#     'label_stats': {'overall_mean': 189.56857142857143,
#      'overall_std': 350.00212184779565,
#      'entity_std': 254.04450316094452},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 83.0 (keep 75.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <ELAPSED_TIME> greater than 83.0 in next 1 days',
#     'label_stats': {'overall_mean': 282.7114285714286,
#      'overall_std': 519.2164697318608,
#      'entity_std': 378.9477267691686},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <DEPARTURE_DELAY> greater than __',
#   'evaluations': [{'description': 'threshold: 18.0 (keep 25.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <DEPARTURE_DELAY> greater than 18.0 in next 1 days',
#     'label_stats': {'overall_mean': 80.94,
#      'overall_std': 168.691398205633,
#      'entity_std': 121.13938064088204},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 0.0 (keep 50.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <DEPARTURE_DELAY> greater than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 168.89714285714285,
#      'overall_std': 338.69335603227904,
#      'entity_std': 234.95799380534058},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: -4.0 (keep 75.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <DEPARTURE_DELAY> greater than -4.0 in next 1 days',
#     'label_stats': {'overall_mean': 274.1142857142857,
#      'overall_std': 544.5157729017365,
#      'entity_std': 371.3174401830421},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <ARRIVAL_DELAY> greater than __',
#   'evaluations': [{'description': 'threshold: 18.0 (keep 25.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <ARRIVAL_DELAY> greater than 18.0 in next 1 days',
#     'label_stats': {'overall_mean': 84.27428571428571,
#      'overall_std': 171.22966756103108,
#      'entity_std': 127.99751906537838},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 0.0 (keep 50.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <ARRIVAL_DELAY> greater than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 171.61142857142858,
#      'overall_std': 324.7627844367363,
#      'entity_std': 240.58292270886895},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: -10.0 (keep 75.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <ARRIVAL_DELAY> greater than -10.0 in next 1 days',
#     'label_stats': {'overall_mean': 279.2685714285714,
#      'overall_std': 522.1545878221061,
#      'entity_std': 378.9188970462504},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <AIR_SYSTEM_DELAY> greater than __',
#   'evaluations': [{'description': 'threshold: 0.0 (keep 25.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <AIR_SYSTEM_DELAY> greater than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 54.72,
#      'overall_std': 106.43061535908869,
#      'entity_std': 84.13594710643015},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 0.0 (keep 50.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <AIR_SYSTEM_DELAY> greater than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 54.72,
#      'overall_std': 106.43061535908869,
#      'entity_std': 84.13594710643015},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 0.0 (keep 75.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <AIR_SYSTEM_DELAY> greater than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 54.72,
#      'overall_std': 106.43061535908869,
#      'entity_std': 84.13594710643015},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <SECURITY_DELAY> greater than __',
#   'evaluations': [{'description': 'threshold: 0.0 (keep 25.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <SECURITY_DELAY> greater than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 0.24571428571428572,
#      'overall_std': 0.8861934187919723,
#      'entity_std': 0.6192762900106705},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 0.0 (keep 50.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <SECURITY_DELAY> greater than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 0.24571428571428572,
#      'overall_std': 0.8861934187919723,
#      'entity_std': 0.6192762900106705},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 0.0 (keep 75.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <SECURITY_DELAY> greater than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 0.24571428571428572,
#      'overall_std': 0.8861934187919723,
#      'entity_std': 0.6192762900106705},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <AIRLINE_DELAY> greater than __',
#   'evaluations': [{'description': 'threshold: 0.0 (keep 25.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <AIRLINE_DELAY> greater than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 49.20285714285714,
#      'overall_std': 102.65198623285875,
#      'entity_std': 72.84820019564816},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 0.0 (keep 50.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <AIRLINE_DELAY> greater than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 49.20285714285714,
#      'overall_std': 102.65198623285875,
#      'entity_std': 72.84820019564816},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 0.0 (keep 75.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <AIRLINE_DELAY> greater than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 49.20285714285714,
#      'overall_std': 102.65198623285875,
#      'entity_std': 72.84820019564816},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <LATE_AIRCRAFT_DELAY> greater than __',
#   'evaluations': [{'description': 'threshold: 0.0 (keep 25.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <LATE_AIRCRAFT_DELAY> greater than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 51.86,
#      'overall_std': 120.01219152355195,
#      'entity_std': 81.81571321581598},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 0.0 (keep 50.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <LATE_AIRCRAFT_DELAY> greater than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 51.86,
#      'overall_std': 120.01219152355195,
#      'entity_std': 81.81571321581598},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 0.0 (keep 75.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <LATE_AIRCRAFT_DELAY> greater than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 51.86,
#      'overall_std': 120.01219152355195,
#      'entity_std': 81.81571321581598},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <WEATHER_DELAY> greater than __',
#   'evaluations': [{'description': 'threshold: 0.0 (keep 25.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <WEATHER_DELAY> greater than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 8.722857142857142,
#      'overall_std': 23.78667797275592,
#      'entity_std': 16.23152822386113},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 0.0 (keep 50.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <WEATHER_DELAY> greater than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 8.722857142857142,
#      'overall_std': 23.78667797275592,
#      'entity_std': 16.23152822386113},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 0.0 (keep 75.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <WEATHER_DELAY> greater than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 8.722857142857142,
#      'overall_std': 23.78667797275592,
#      'entity_std': 16.23152822386113},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <DAY_OF_WEEK> equal to __',
#   'evaluations': [{'description': 'threshold: 2',
#     'problem': 'For each <AIRLINE> predict the number of records with <DAY_OF_WEEK> equal to 2 in next 1 days',
#     'label_stats': {'overall_mean': 87.12857142857143,
#      'overall_std': 384.7030885326119,
#      'entity_std': 295.4932111392733},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 5',
#     'problem': 'For each <AIRLINE> predict the number of records with <DAY_OF_WEEK> equal to 5 in next 1 days',
#     'label_stats': {'overall_mean': 45.73714285714286,
#      'overall_std': 284.982063681924,
#      'entity_std': 224.06532458556066},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 4',
#     'problem': 'For each <AIRLINE> predict the number of records with <DAY_OF_WEEK> equal to 4 in next 1 days',
#     'label_stats': {'overall_mean': 45.74,
#      'overall_std': 286.0461268496993,
#      'entity_std': 224.0793216698051},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <FLIGHT_NUMBER> equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <TAIL_NUMBER> equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <ORIGIN_AIRPORT> equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <DESTINATION_AIRPORT> equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <CANCELLED> equal to __',
#   'evaluations': [{'description': 'threshold: 0',
#     'problem': 'For each <AIRLINE> predict the number of records with <CANCELLED> equal to 0 in next 1 days',
#     'label_stats': {'overall_mean': 380.7257142857143,
#      'overall_std': 711.586110979392,
#      'entity_std': 510.1138149560369},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 1',
#     'problem': 'For each <AIRLINE> predict the number of records with <CANCELLED> equal to 1 in next 1 days',
#     'label_stats': {'overall_mean': 9.528571428571428,
#      'overall_std': 28.513215697072038,
#      'entity_std': 16.257059058755235},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <CANCELLATION_REASON> equal to __',
#   'evaluations': [{'description': 'threshold: -',
#     'problem': 'For each <AIRLINE> predict the number of records with <CANCELLATION_REASON> equal to - in next 1 days',
#     'label_stats': {'overall_mean': 380.7257142857143,
#      'overall_std': 711.586110979392,
#      'entity_std': 510.1138149560369},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: A',
#     'problem': 'For each <AIRLINE> predict the number of records with <CANCELLATION_REASON> equal to A in next 1 days',
#     'label_stats': {'overall_mean': 3.42,
#      'overall_std': 10.755099787011343,
#      'entity_std': 6.1370390085066004},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: C',
#     'problem': 'For each <AIRLINE> predict the number of records with <CANCELLATION_REASON> equal to C in next 1 days',
#     'label_stats': {'overall_mean': 2.6714285714285713,
#      'overall_std': 13.661961194260119,
#      'entity_std': 5.91711840770885},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <DAY_OF_WEEK> not equal to __',
#   'evaluations': [{'description': 'threshold: 2',
#     'problem': 'For each <AIRLINE> predict the number of records with <DAY_OF_WEEK> not equal to 2 in next 1 days',
#     'label_stats': {'overall_mean': 303.1257142857143,
#      'overall_std': 660.0373289629078,
#      'entity_std': 488.74880363316635},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 5',
#     'problem': 'For each <AIRLINE> predict the number of records with <DAY_OF_WEEK> not equal to 5 in next 1 days',
#     'label_stats': {'overall_mean': 344.51714285714286,
#      'overall_std': 693.6307403740384,
#      'entity_std': 504.7574807357228},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 4',
#     'problem': 'For each <AIRLINE> predict the number of records with <DAY_OF_WEEK> not equal to 4 in next 1 days',
#     'label_stats': {'overall_mean': 344.51428571428573,
#      'overall_std': 693.193841017424,
#      'entity_std': 504.75296520465093},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <FLIGHT_NUMBER> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <TAIL_NUMBER> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <ORIGIN_AIRPORT> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <DESTINATION_AIRPORT> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <CANCELLED> not equal to __',
#   'evaluations': [{'description': 'threshold: 0',
#     'problem': 'For each <AIRLINE> predict the number of records with <CANCELLED> not equal to 0 in next 1 days',
#     'label_stats': {'overall_mean': 9.528571428571428,
#      'overall_std': 28.513215697072038,
#      'entity_std': 16.257059058755235},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 1',
#     'problem': 'For each <AIRLINE> predict the number of records with <CANCELLED> not equal to 1 in next 1 days',
#     'label_stats': {'overall_mean': 380.7257142857143,
#      'overall_std': 711.586110979392,
#      'entity_std': 510.1138149560369},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <CANCELLATION_REASON> not equal to __',
#   'evaluations': [{'description': 'threshold: -',
#     'problem': 'For each <AIRLINE> predict the number of records with <CANCELLATION_REASON> not equal to - in next 1 days',
#     'label_stats': {'overall_mean': 9.528571428571428,
#      'overall_std': 28.513215697072038,
#      'entity_std': 16.257059058755235},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 0.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: A',
#     'problem': 'For each <AIRLINE> predict the number of records with <CANCELLATION_REASON> not equal to A in next 1 days',
#     'label_stats': {'overall_mean': 386.8342857142857,
#      'overall_std': 721.3775916131806,
#      'entity_std': 518.2966690517179},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: C',
#     'problem': 'For each <AIRLINE> predict the number of records with <CANCELLATION_REASON> not equal to C in next 1 days',
#     'label_stats': {'overall_mean': 387.58285714285716,
#      'overall_std': 725.4303729454928,
#      'entity_std': 519.4469900611593},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <SCHEDULED_DEPARTURE_HOUR> less than __',
#   'evaluations': [{'description': 'threshold: 9 (keep 25.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <SCHEDULED_DEPARTURE_HOUR> less than 9 in next 1 days',
#     'label_stats': {'overall_mean': 87.03142857142858,
#      'overall_std': 162.62579881684312,
#      'entity_std': 117.41381602357319},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 13 (keep 50.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <SCHEDULED_DEPARTURE_HOUR> less than 13 in next 1 days',
#     'label_stats': {'overall_mean': 185.78857142857143,
#      'overall_std': 346.50380477929906,
#      'entity_std': 248.9203190833279},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 17 (keep 75.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <SCHEDULED_DEPARTURE_HOUR> less than 17 in next 1 days',
#     'label_stats': {'overall_mean': 284.39428571428573,
#      'overall_std': 532.2379209890776,
#      'entity_std': 380.63307979869217},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <SCHEDULED_TIME> less than __',
#   'evaluations': [{'description': 'threshold: 88.0 (keep 25.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <SCHEDULED_TIME> less than 88.0 in next 1 days',
#     'label_stats': {'overall_mean': 106.21142857142857,
#      'overall_std': 230.23835074787613,
#      'entity_std': 142.64008716214644},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 124.0 (keep 50.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <SCHEDULED_TIME> less than 124.0 in next 1 days',
#     'label_stats': {'overall_mean': 201.12285714285716,
#      'overall_std': 422.3971987094032,
#      'entity_std': 270.07099851839314},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 177.0 (keep 75.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <SCHEDULED_TIME> less than 177.0 in next 1 days',
#     'label_stats': {'overall_mean': 300.4085714285714,
#      'overall_std': 592.7480712128304,
#      'entity_std': 402.9476462951845},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <ELAPSED_TIME> less than __',
#   'evaluations': [{'description': 'threshold: 84.0 (keep 25.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <ELAPSED_TIME> less than 84.0 in next 1 days',
#     'label_stats': {'overall_mean': 107.54285714285714,
#      'overall_std': 236.346349103797,
#      'entity_std': 144.7410994695371},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 120.0 (keep 50.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <ELAPSED_TIME> less than 120.0 in next 1 days',
#     'label_stats': {'overall_mean': 200.68571428571428,
#      'overall_std': 424.0156514246393,
#      'entity_std': 269.40772651213354},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 173.0 (keep 75.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <ELAPSED_TIME> less than 173.0 in next 1 days',
#     'label_stats': {'overall_mean': 300.38,
#      'overall_std': 595.3740348002134,
#      'entity_std': 402.7180150380563},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <DEPARTURE_DELAY> less than __',
#   'evaluations': [{'description': 'threshold: -3.0 (keep 25.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <DEPARTURE_DELAY> less than -3.0 in next 1 days',
#     'label_stats': {'overall_mean': 116.14,
#      'overall_std': 207.80804425513188,
#      'entity_std': 162.61829265259976},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 1.0 (keep 50.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <DEPARTURE_DELAY> less than 1.0 in next 1 days',
#     'label_stats': {'overall_mean': 221.35714285714286,
#      'overall_std': 414.54978111248374,
#      'entity_std': 301.7042022594473},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 19.0 (keep 75.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <DEPARTURE_DELAY> less than 19.0 in next 1 days',
#     'label_stats': {'overall_mean': 309.3142857142857,
#      'overall_std': 583.1653120895393,
#      'entity_std': 416.5273467810216},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <ARRIVAL_DELAY> less than __',
#   'evaluations': [{'description': 'threshold: -9.0 (keep 25.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <ARRIVAL_DELAY> less than -9.0 in next 1 days',
#     'label_stats': {'overall_mean': 110.98571428571428,
#      'overall_std': 228.42847538638202,
#      'entity_std': 154.4322331778545},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 1.0 (keep 50.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <ARRIVAL_DELAY> less than 1.0 in next 1 days',
#     'label_stats': {'overall_mean': 218.64285714285714,
#      'overall_std': 429.7379346171101,
#      'entity_std': 298.10302748401637},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 19.0 (keep 75.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <ARRIVAL_DELAY> less than 19.0 in next 1 days',
#     'label_stats': {'overall_mean': 305.98,
#      'overall_std': 585.0273518880488,
#      'entity_std': 412.5532315585575},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <AIR_SYSTEM_DELAY> less than __',
#   'evaluations': [{'description': 'threshold: 0.0 (keep 25.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <AIR_SYSTEM_DELAY> less than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 0.0,
#      'overall_std': 0.0,
#      'entity_std': 0.0},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 1.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 1.0}},
#    {'description': 'threshold: 1.0 (keep 50.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <AIR_SYSTEM_DELAY> less than 1.0 in next 1 days',
#     'label_stats': {'overall_mean': 335.5342857142857,
#      'overall_std': 642.4793028096512,
#      'entity_std': 450.3059568309941},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 1.0 (keep 75.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <AIR_SYSTEM_DELAY> less than 1.0 in next 1 days',
#     'label_stats': {'overall_mean': 335.5342857142857,
#      'overall_std': 642.4793028096512,
#      'entity_std': 450.3059568309941},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <SECURITY_DELAY> less than __',
#   'evaluations': [{'description': 'threshold: 0.0 (keep 25.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <SECURITY_DELAY> less than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 0.0,
#      'overall_std': 0.0,
#      'entity_std': 0.0},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 1.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 1.0}},
#    {'description': 'threshold: 0.0 (keep 50.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <SECURITY_DELAY> less than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 0.0,
#      'overall_std': 0.0,
#      'entity_std': 0.0},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 1.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 1.0}},
#    {'description': 'threshold: 0.0 (keep 75.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <SECURITY_DELAY> less than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 0.0,
#      'overall_std': 0.0,
#      'entity_std': 0.0},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 1.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 1.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <AIRLINE_DELAY> less than __',
#   'evaluations': [{'description': 'threshold: 0.0 (keep 25.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <AIRLINE_DELAY> less than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 0.0,
#      'overall_std': 0.0,
#      'entity_std': 0.0},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 1.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 1.0}},
#    {'description': 'threshold: 1.0 (keep 50.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <AIRLINE_DELAY> less than 1.0 in next 1 days',
#     'label_stats': {'overall_mean': 341.0514285714286,
#      'overall_std': 637.8598974568581,
#      'entity_std': 457.4914471283961},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 1.0 (keep 75.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <AIRLINE_DELAY> less than 1.0 in next 1 days',
#     'label_stats': {'overall_mean': 341.0514285714286,
#      'overall_std': 637.8598974568581,
#      'entity_std': 457.4914471283961},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <LATE_AIRCRAFT_DELAY> less than __',
#   'evaluations': [{'description': 'threshold: 0.0 (keep 25.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <LATE_AIRCRAFT_DELAY> less than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 0.0,
#      'overall_std': 0.0,
#      'entity_std': 0.0},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 1.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 1.0}},
#    {'description': 'threshold: 1.0 (keep 50.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <LATE_AIRCRAFT_DELAY> less than 1.0 in next 1 days',
#     'label_stats': {'overall_mean': 338.39428571428573,
#      'overall_std': 631.0276552431222,
#      'entity_std': 454.2123959588806},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 1.0 (keep 75.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <LATE_AIRCRAFT_DELAY> less than 1.0 in next 1 days',
#     'label_stats': {'overall_mean': 338.39428571428573,
#      'overall_std': 631.0276552431222,
#      'entity_std': 454.2123959588806},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the number of records with <WEATHER_DELAY> less than __',
#   'evaluations': [{'description': 'threshold: 0.0 (keep 25.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <WEATHER_DELAY> less than 0.0 in next 1 days',
#     'label_stats': {'overall_mean': 0.0,
#      'overall_std': 0.0,
#      'entity_std': 0.0},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 1.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 1.0}},
#    {'description': 'threshold: 1.0 (keep 50.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <WEATHER_DELAY> less than 1.0 in next 1 days',
#     'label_stats': {'overall_mean': 381.5314285714286,
#      'overall_std': 715.7105104206105,
#      'entity_std': 511.1938245062088},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}},
#    {'description': 'threshold: 1.0 (keep 75.0%)',
#     'problem': 'For each <AIRLINE> predict the number of records with <WEATHER_DELAY> less than 1.0 in next 1 days',
#     'label_stats': {'overall_mean': 381.5314285714286,
#      'overall_std': 715.7105104206105,
#      'entity_std': 511.1938245062088},
#     'N_train': 210,
#     'N_test': 112,
#     'R2': {'LinearRegression': 0.0,
#      'DecisionTreeRegressor': 1.0,
#      'AdaBoost': 0.0}}]},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <SCHEDULED_DEPARTURE_HOUR> in all related records',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <SCHEDULED_TIME> in all related records',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <ELAPSED_TIME> in all related records',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <DEPARTURE_DELAY> in all related records',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <ARRIVAL_DELAY> in all related records',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <AIR_SYSTEM_DELAY> in all related records',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <SECURITY_DELAY> in all related records',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <AIRLINE_DELAY> in all related records',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <LATE_AIRCRAFT_DELAY> in all related records',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <WEATHER_DELAY> in all related records',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <SCHEDULED_DEPARTURE_HOUR> in all related records with <SCHEDULED_DEPARTURE_HOUR> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <SCHEDULED_TIME> in all related records with <SCHEDULED_DEPARTURE_HOUR> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <ELAPSED_TIME> in all related records with <SCHEDULED_DEPARTURE_HOUR> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <DEPARTURE_DELAY> in all related records with <SCHEDULED_DEPARTURE_HOUR> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <ARRIVAL_DELAY> in all related records with <SCHEDULED_DEPARTURE_HOUR> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <AIR_SYSTEM_DELAY> in all related records with <SCHEDULED_DEPARTURE_HOUR> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <SECURITY_DELAY> in all related records with <SCHEDULED_DEPARTURE_HOUR> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <AIRLINE_DELAY> in all related records with <SCHEDULED_DEPARTURE_HOUR> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <LATE_AIRCRAFT_DELAY> in all related records with <SCHEDULED_DEPARTURE_HOUR> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <WEATHER_DELAY> in all related records with <SCHEDULED_DEPARTURE_HOUR> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <SCHEDULED_DEPARTURE_HOUR> in all related records with <SCHEDULED_TIME> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <SCHEDULED_TIME> in all related records with <SCHEDULED_TIME> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <ELAPSED_TIME> in all related records with <SCHEDULED_TIME> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <DEPARTURE_DELAY> in all related records with <SCHEDULED_TIME> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <ARRIVAL_DELAY> in all related records with <SCHEDULED_TIME> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <AIR_SYSTEM_DELAY> in all related records with <SCHEDULED_TIME> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <SECURITY_DELAY> in all related records with <SCHEDULED_TIME> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <AIRLINE_DELAY> in all related records with <SCHEDULED_TIME> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <LATE_AIRCRAFT_DELAY> in all related records with <SCHEDULED_TIME> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <WEATHER_DELAY> in all related records with <SCHEDULED_TIME> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <SCHEDULED_DEPARTURE_HOUR> in all related records with <ELAPSED_TIME> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <SCHEDULED_TIME> in all related records with <ELAPSED_TIME> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <ELAPSED_TIME> in all related records with <ELAPSED_TIME> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <DEPARTURE_DELAY> in all related records with <ELAPSED_TIME> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <ARRIVAL_DELAY> in all related records with <ELAPSED_TIME> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <AIR_SYSTEM_DELAY> in all related records with <ELAPSED_TIME> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <SECURITY_DELAY> in all related records with <ELAPSED_TIME> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <AIRLINE_DELAY> in all related records with <ELAPSED_TIME> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <LATE_AIRCRAFT_DELAY> in all related records with <ELAPSED_TIME> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <WEATHER_DELAY> in all related records with <ELAPSED_TIME> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <SCHEDULED_DEPARTURE_HOUR> in all related records with <DEPARTURE_DELAY> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <SCHEDULED_TIME> in all related records with <DEPARTURE_DELAY> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <ELAPSED_TIME> in all related records with <DEPARTURE_DELAY> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <DEPARTURE_DELAY> in all related records with <DEPARTURE_DELAY> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <ARRIVAL_DELAY> in all related records with <DEPARTURE_DELAY> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <AIR_SYSTEM_DELAY> in all related records with <DEPARTURE_DELAY> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <SECURITY_DELAY> in all related records with <DEPARTURE_DELAY> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <AIRLINE_DELAY> in all related records with <DEPARTURE_DELAY> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <LATE_AIRCRAFT_DELAY> in all related records with <DEPARTURE_DELAY> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <WEATHER_DELAY> in all related records with <DEPARTURE_DELAY> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the total <SCHEDULED_DEPARTURE_HOUR> in all related records with <ARRIVAL_DELAY> greater than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
# ...
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <ARRIVAL_DELAY> in all related records with <DAY_OF_WEEK> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <AIR_SYSTEM_DELAY> in all related records with <DAY_OF_WEEK> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SECURITY_DELAY> in all related records with <DAY_OF_WEEK> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <AIRLINE_DELAY> in all related records with <DAY_OF_WEEK> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <LATE_AIRCRAFT_DELAY> in all related records with <DAY_OF_WEEK> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <WEATHER_DELAY> in all related records with <DAY_OF_WEEK> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SCHEDULED_DEPARTURE_HOUR> in all related records with <FLIGHT_NUMBER> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SCHEDULED_TIME> in all related records with <FLIGHT_NUMBER> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <ELAPSED_TIME> in all related records with <FLIGHT_NUMBER> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <DEPARTURE_DELAY> in all related records with <FLIGHT_NUMBER> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <ARRIVAL_DELAY> in all related records with <FLIGHT_NUMBER> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <AIR_SYSTEM_DELAY> in all related records with <FLIGHT_NUMBER> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SECURITY_DELAY> in all related records with <FLIGHT_NUMBER> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <AIRLINE_DELAY> in all related records with <FLIGHT_NUMBER> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <LATE_AIRCRAFT_DELAY> in all related records with <FLIGHT_NUMBER> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <WEATHER_DELAY> in all related records with <FLIGHT_NUMBER> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SCHEDULED_DEPARTURE_HOUR> in all related records with <TAIL_NUMBER> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SCHEDULED_TIME> in all related records with <TAIL_NUMBER> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <ELAPSED_TIME> in all related records with <TAIL_NUMBER> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <DEPARTURE_DELAY> in all related records with <TAIL_NUMBER> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <ARRIVAL_DELAY> in all related records with <TAIL_NUMBER> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <AIR_SYSTEM_DELAY> in all related records with <TAIL_NUMBER> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SECURITY_DELAY> in all related records with <TAIL_NUMBER> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <AIRLINE_DELAY> in all related records with <TAIL_NUMBER> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <LATE_AIRCRAFT_DELAY> in all related records with <TAIL_NUMBER> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <WEATHER_DELAY> in all related records with <TAIL_NUMBER> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SCHEDULED_DEPARTURE_HOUR> in all related records with <ORIGIN_AIRPORT> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SCHEDULED_TIME> in all related records with <ORIGIN_AIRPORT> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <ELAPSED_TIME> in all related records with <ORIGIN_AIRPORT> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <DEPARTURE_DELAY> in all related records with <ORIGIN_AIRPORT> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <ARRIVAL_DELAY> in all related records with <ORIGIN_AIRPORT> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <AIR_SYSTEM_DELAY> in all related records with <ORIGIN_AIRPORT> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SECURITY_DELAY> in all related records with <ORIGIN_AIRPORT> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <AIRLINE_DELAY> in all related records with <ORIGIN_AIRPORT> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <LATE_AIRCRAFT_DELAY> in all related records with <ORIGIN_AIRPORT> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <WEATHER_DELAY> in all related records with <ORIGIN_AIRPORT> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SCHEDULED_DEPARTURE_HOUR> in all related records with <DESTINATION_AIRPORT> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SCHEDULED_TIME> in all related records with <DESTINATION_AIRPORT> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <ELAPSED_TIME> in all related records with <DESTINATION_AIRPORT> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <DEPARTURE_DELAY> in all related records with <DESTINATION_AIRPORT> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <ARRIVAL_DELAY> in all related records with <DESTINATION_AIRPORT> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <AIR_SYSTEM_DELAY> in all related records with <DESTINATION_AIRPORT> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SECURITY_DELAY> in all related records with <DESTINATION_AIRPORT> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <AIRLINE_DELAY> in all related records with <DESTINATION_AIRPORT> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <LATE_AIRCRAFT_DELAY> in all related records with <DESTINATION_AIRPORT> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <WEATHER_DELAY> in all related records with <DESTINATION_AIRPORT> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SCHEDULED_DEPARTURE_HOUR> in all related records with <CANCELLED> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SCHEDULED_TIME> in all related records with <CANCELLED> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <ELAPSED_TIME> in all related records with <CANCELLED> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <DEPARTURE_DELAY> in all related records with <CANCELLED> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <ARRIVAL_DELAY> in all related records with <CANCELLED> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <AIR_SYSTEM_DELAY> in all related records with <CANCELLED> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SECURITY_DELAY> in all related records with <CANCELLED> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <AIRLINE_DELAY> in all related records with <CANCELLED> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <LATE_AIRCRAFT_DELAY> in all related records with <CANCELLED> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <WEATHER_DELAY> in all related records with <CANCELLED> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SCHEDULED_DEPARTURE_HOUR> in all related records with <CANCELLATION_REASON> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SCHEDULED_TIME> in all related records with <CANCELLATION_REASON> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <ELAPSED_TIME> in all related records with <CANCELLATION_REASON> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <DEPARTURE_DELAY> in all related records with <CANCELLATION_REASON> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <ARRIVAL_DELAY> in all related records with <CANCELLATION_REASON> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <AIR_SYSTEM_DELAY> in all related records with <CANCELLATION_REASON> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SECURITY_DELAY> in all related records with <CANCELLATION_REASON> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <AIRLINE_DELAY> in all related records with <CANCELLATION_REASON> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <LATE_AIRCRAFT_DELAY> in all related records with <CANCELLATION_REASON> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <WEATHER_DELAY> in all related records with <CANCELLATION_REASON> not equal to __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SCHEDULED_DEPARTURE_HOUR> in all related records with <SCHEDULED_DEPARTURE_HOUR> less than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SCHEDULED_TIME> in all related records with <SCHEDULED_DEPARTURE_HOUR> less than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <ELAPSED_TIME> in all related records with <SCHEDULED_DEPARTURE_HOUR> less than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <DEPARTURE_DELAY> in all related records with <SCHEDULED_DEPARTURE_HOUR> less than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <ARRIVAL_DELAY> in all related records with <SCHEDULED_DEPARTURE_HOUR> less than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <AIR_SYSTEM_DELAY> in all related records with <SCHEDULED_DEPARTURE_HOUR> less than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SECURITY_DELAY> in all related records with <SCHEDULED_DEPARTURE_HOUR> less than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <AIRLINE_DELAY> in all related records with <SCHEDULED_DEPARTURE_HOUR> less than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <LATE_AIRCRAFT_DELAY> in all related records with <SCHEDULED_DEPARTURE_HOUR> less than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <WEATHER_DELAY> in all related records with <SCHEDULED_DEPARTURE_HOUR> less than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SCHEDULED_DEPARTURE_HOUR> in all related records with <SCHEDULED_TIME> less than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <SCHEDULED_TIME> in all related records with <SCHEDULED_TIME> less than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <ELAPSED_TIME> in all related records with <SCHEDULED_TIME> less than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <DEPARTURE_DELAY> in all related records with <SCHEDULED_TIME> less than __',
#   'evaluations': []},
#  {'problem_type': 'regression',
#   'template_nl': 'For each <AIRLINE> predict the maximum of <ARRIVAL_DELAY> in all related records with <SCHEDULED_TIME> less than __',
#   'evaluations': []},
#  ...]

# %%
import copy

p = copy.deepcopy(problems)
for i in problems:
    # print(i)
    # print(i.operations)
    l = []
    for e in i.operations:
        l.append(e.column_name)
    if len(set(l)) == 1 and None not in l:
        p.remove(i)
